# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
path = './healthcare_noshows.csv'

my_data = pd.read_csv(path)

# %%
my_data.head()

# my_data.dropna(axis=0, subset=['ScheduledDay', 'AppointmentDay'], inplace=True)

# drop id列
my_data.drop(['PatientId', 'AppointmentID'], axis=1, inplace=True)

# %%
my_data.head()
# Out:
#   Gender ScheduledDay AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0      F   2016-04-29     2016-04-29   62    JARDIM DA PENHA        False
# 1      M   2016-04-29     2016-04-29   56    JARDIM DA PENHA        False
# 2      F   2016-04-29     2016-04-29   62      MATA DA PRAIA        False
# 3      F   2016-04-29     2016-04-29    8  PONTAL DE CAMBURI        False
# 4      F   2016-04-29     2016-04-29   56    JARDIM DA PENHA        False
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received  Showed_up  \
# 0          True     False       False    False         False       True
# 1         False     False       False    False         False       True
# 2         False     False       False    False         False       True
# 3         False     False       False    False         False       True
# 4          True      True       False    False         False       True
#
#    Date.diff
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
plt.figure(figsize=(16,6))

sns.lineplot(data=my_data, x='Age', y='Alcoholism', hue='Gender', style='Gender', markers=True, dashes=False)
# Out:
# <Axes: xlabel='Age', ylabel='Alcoholism'>

# %%
# KDE
plt.figure(figsize=(16,6))
sns.kdeplot(data=my_data, x='Age', shade=True, hue='Gender', multiple='stack', palette='coolwarm')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\11620\AppData\Local\Temp\ipykernel_36156\948863384.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=my_data, x='Age', shade=True, hue='Gender', multiple='stack', palette='coolwarm')
